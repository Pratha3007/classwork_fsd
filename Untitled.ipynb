# %%
import numpy as np
import pandas as pd
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=pd.DataFrame([[1,np.nan,3,4],[2,4,np.nan,8],[np.nan,4,5,9],[np.nan,1,np.nan,3],[np.nan,np.nan,np.nan,np.nan]],columns=["A","B","C","D"])
df
# Out:
#      A    B    C    D
# 0  1.0  NaN  3.0  4.0
# 1  2.0  4.0  NaN  8.0
# 2  NaN  4.0  5.0  9.0
# 3  NaN  1.0  NaN  3.0
# 4  NaN  NaN  NaN  NaN

# %%
df.isna().sum()
# Out:
# A    3
# B    2
# C    3
# D    1
# dtype: int64

# %%
df.isna()
# Out:
#        A      B      C      D
# 0  False   True  False  False
# 1  False  False   True  False
# 2   True  False  False  False
# 3   True  False   True  False
# 4   True   True   True   True

# %%
df.dropna(how="any", axis=0)
# Out:
#      A    B    C    D
# 5  1.0  1.0  1.0  1.0

# %%
df=pd.DataFrame([[1,np.nan,3,4],[2,4,np.nan,8],[np.nan,4,5,9],[np.nan,1,np.nan,3],[np.nan,np.nan,np.nan,np.nan],[1,1,1,1]],columns=["A","B","C","D"])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8b8343ba2743> in <module>
# ----> 1 df=pd.DataFrame([[1,np.nan,3,4],[2,4,np.nan,8],[np.nan,4,5,9],[np.nan,1,np.nan,3],[np.nan,np.nan,np.nan,np.nan],[1,1,1,1]],columns=["A","B","C","D"])
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df.dropna(how="any", axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5]

# %%
df.dropna(how="all", axis=0) #all: jema bdhi blank hoi a row del thse
# Out:
#      A    B    C    D
# 0  1.0  NaN  3.0  4.0
# 1  2.0  4.0  NaN  8.0
# 2  NaN  4.0  5.0  9.0
# 3  NaN  1.0  NaN  3.0
# 5  1.0  1.0  1.0  1.0

# %%
df.dropna(subset=["A"])
# Out:
#      A    B    C    D
# 0  1.0  NaN  3.0  4.0
# 1  2.0  4.0  NaN  8.0
# 5  1.0  1.0  1.0  1.0

# %%
df.dropna(subset=["B","D"],how="all")
# Out:
#      A    B    C    D
# 0  1.0  NaN  3.0  4.0
# 1  2.0  4.0  NaN  8.0
# 2  NaN  4.0  5.0  9.0
# 3  NaN  1.0  NaN  3.0
# 5  1.0  1.0  1.0  1.0

# %%
df.dropna(subset=["B","D"])
# Out:
#      A    B    C    D
# 1  2.0  4.0  NaN  8.0
# 2  NaN  4.0  5.0  9.0
# 3  NaN  1.0  NaN  3.0
# 5  1.0  1.0  1.0  1.0

# %%
df.dropna(thresh=2) # agar 2 kato 2 thi vadre values lakeli hoi to drop ni krse
# biji bdha
# Out:
#      A    B    C    D
# 0  1.0  NaN  3.0  4.0
# 1  2.0  4.0  NaN  8.0
# 2  NaN  4.0  5.0  9.0
# 3  NaN  1.0  NaN  3.0
# 5  1.0  1.0  1.0  1.0

# %%
df.dropna(thresh=3)  # agar 3 kato 3 thi vadre values lakeli hoi to drop ni krse
# Out:
#      A    B    C    D
# 0  1.0  NaN  3.0  4.0
# 1  2.0  4.0  NaN  8.0
# 2  NaN  4.0  5.0  9.0
# 5  1.0  1.0  1.0  1.0

# %%
df.fillna(df.mean())
# Out:
#           A    B    C    D
# 0  1.000000  2.5  3.0  4.0
# 1  2.000000  4.0  3.0  8.0
# 2  1.333333  4.0  5.0  9.0
# 3  1.333333  1.0  3.0  3.0
# 4  1.333333  2.5  3.0  5.0
# 5  1.000000  1.0  1.0  1.0

# %%
df
# Out:
#      A    B    C    D
# 0  1.0  NaN  3.0  4.0
# 1  2.0  4.0  NaN  8.0
# 2  NaN  4.0  5.0  9.0
# 3  NaN  1.0  NaN  3.0
# 4  NaN  NaN  NaN  NaN
# 5  1.0  1.0  1.0  1.0

# %%
df["A"]=df["A"].fillna(df["A"].mean())

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.duplicated(subset=["Sex","Survived"]).sum()
# Out:
# 887

# %%
df.drop("Cabin",axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Sex"]=="male"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
df[df["Sex"]!="male"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Sex"]!="male"].index
# Out:
# Int64Index([  1,   2,   3,   8,   9,  10,  11,  14,  15,  18,
#             ...
#             866, 871, 874, 875, 879, 880, 882, 885, 887, 888],
#            dtype='int64', length=314)

# %%
df[(df["Sex"]=="male") & (df["Survived"]==1)] # survived and male hovu joye
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
df[(df["Sex"]!="male") & (df["Survived"]!=1)] #  not survived and female hovu joye
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values("Age")
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values("Age",ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values("Age",ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values(["Age","Name"] ,ascending=[False,True])
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# ..           ...       ...     ...                                   ...
# 55            56         1       1                     Woolner, Mr. Hugh
# 354          355         0       3                     Yousif, Mr. Wazli
# 495          496         0       3                 Yousseff, Mr. Gerious
# 240          241         0       3                 Zabour, Miss. Thamine
# 868          869         0       3           van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
df.sort_values(["Age","Name"] ,ascending=[False,True]).sort_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ds=df.set_index("Name")
ds
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
ds.sort_index(axis=0)
# Out:
#                                        PassengerId  Survived  Pclass     Sex  \
# Name
# Abbing, Mr. Anthony                            846         0       3    male
# Abbott, Mr. Rossmore Edward                    747         0       3    male
# Abbott, Mrs. Stanton (Rosa Hunt)               280         1       3  female
# Abelson, Mr. Samuel                            309         0       2    male
# Abelson, Mrs. Samuel (Hannah Wizosky)          875         1       2  female
# ...                                            ...       ...     ...     ...
# de Mulder, Mr. Theodore                        287         1       3    male
# de Pelsmaeker, Mr. Alfons                      283         0       3    male
# del Carlo, Mr. Sebastiano                      362         0       2    male
# van Billiard, Mr. Austin Blyler                154         0       3    male
# van Melkebeke, Mr. Philemon                    869         0       3    male
#
# ...

# %%
ds.sort_index(axis=1)
# Out:
#                                                      Age Cabin Embarked  \
# Name
# Braund, Mr. Owen Harris                             22.0   NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0   C85        C
# Heikkinen, Miss. Laina                              26.0   NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0  C123        S
# Allen, Mr. William Henry                            35.0   NaN        S
# ...                                                  ...   ...      ...
# Montvila, Rev. Juozas                               27.0   NaN        S
# Graham, Miss. Margaret Edith                        19.0   B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN   NaN        S
# Behr, Mr. Karl Howell                               26.0  C148        C
# Dooley, Mr. Patrick                                 32.0   NaN        Q
#
#                                                        Fare  Parch  \
# Name
# ...

# %%
df.sum()
